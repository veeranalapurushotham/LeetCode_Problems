# %% [markdown]
# ***1.You are given an m x n integer grid accounts where accounts[i][j] is the amount of money the i​​​​​​​​​​​th​​​​ customer has in the j​​​​​​​​​​​th​​​​ bank. Return the wealth that the richest customer has.
#
# A customer's wealth is the amount of money they have in all their bank accounts. The richest customer is the customer that has the maximum wealth.
#
#
#
# Example 1:
#
# Input: accounts = [[1,2,3],[3,2,1]]
# Output: 6
# Explanation:
# 1st customer has wealth = 1 + 2 + 3 = 6
# 2nd customer has wealth = 3 + 2 + 1 = 6
# Both customers are considered the richest with a wealth of 6 each, so return 6***

# %%
class Solution(object):
    def maximumWealth(self, accounts):
        add=[0]*(len(accounts))
        for i in range(len(accounts)):
            sum=0
            for j in range(len(accounts[0])):
                sum=sum+accounts[i][j]
            add[i]=sum
        '''for i in range(len(add)):
            for j in range(i+1,len(add)):
                if add[i]>add[j]:
                    temp=add[j]
                    add[j]=add[i]
                    add[i]=temp
        return add[len(add)-1]'''
        return max(add)
obj=Solution()
print(obj.maximumWealth([[1,2,3],[3,2,1]]))
# Out:
# 6

# %% [markdown]
# ***2. Given a sorted array of distinct integers and a target value, return the index if the target is found. If not, return the index where it would be if it were inserted in order.
#
# You must write an algorithm with O(log n) runtime complexity.
#
#
#
# Example 1:
#
# Input: nums = [1,3,5,6], target = 5
# Output: 2
# Example 2:
#
# Input: nums = [1,3,5,6], target = 2
# Output: 1
# Example 3:
#
# Input: nums = [1,3,5,6], target = 7***

# %%
class Solution(object):
    def searchInsert(self, nums, target):
        if target<nums[0]:
            return 0
        else:
            for i in range(len(nums)):
                if nums[i]==target:
                    return i
            for i in range(len(nums)):
                if i==len(nums)-1:
                    return i+1
                else :
                    if nums[i]<target<nums[i+1]:
                        return i+1
obj=Solution()
print(obj.searchInsert([1,3,5,6],5))
# Out:
# 2

# %% [markdown]
# ***3.You are given a positive integer array nums.
#
# The element sum is the sum of all the elements in nums.
# The digit sum is the sum of all the digits (not necessarily distinct) that appear in nums.
# Return the absolute difference between the element sum and digit sum of nums.
#
# Note that the absolute difference between two integers x and y is defined as |x - y|.
#
#
#
# Example 1:
#
# Input: nums = [1,15,6,3]
# Output: 9
# Explanation:
# The element sum of nums is 1 + 15 + 6 + 3 = 25.
# The digit sum of nums is 1 + 1 + 5 + 6 + 3 = 16.
# The absolute difference between the element sum and digit sum is |25 - 16| = 9.***

# %%
class Solution(object):
    def differenceOfSum(self, nums):
        sum=0
        for i in nums:
            sum=sum+i
        sum1=0
        for i in nums:
            while(i>0):
                sum1=sum1+i%10
                i=i//10
        return abs(sum-sum1)
obj=Solution()
print(obj.differenceOfSum([1,15,6,3]))
# Out:
# 9

# %% [markdown]
# ***Given an array nums with n objects colored red, white, or blue, sort them in-place so that objects of the same color are adjacent, with the colors in the order red, white, and blue.
#
# We will use the integers 0, 1, and 2 to represent the color red, white, and blue, respectively.
#
# You must solve this problem without using the library's sort function.
#
#
#
# Example 1:
#
# Input: nums = [2,0,2,1,1,0]
# Output: [0,0,1,1,2,2]***

# %%
class Solution(object):
    def sortColors(self, nums):
        for j in range(len(nums)):
            for i in range(len(nums)-1):
                if nums[i]>nums[i+1]:
                    temp=nums[i]
                    nums[i]=nums[i+1]
                    nums[i+1]=temp
        return nums
        
obj=Solution()
print(obj.sortColors([2,0,2,1,1,0]))
# Out:
# [0, 0, 1, 1, 2, 2]

# %% [markdown]
# ***Given an array of integers nums which is sorted in ascending order, and an integer target, write a function to search target in nums. If target exists, then return its index. Otherwise, return -1.
#
# You must write an algorithm with O(log n) runtime complexity.
#
#
#
# Example 1:
#
# Input: nums = [-1,0,3,5,9,12], target = 9
# Output: 4
# Explanation: 9 exists in nums and its index is 4***

# %%
class Solution(object):
    def search(self, nums, target):
       low=0
       k=False
       high=len(nums)-1
       while low<=high:
            mid=(low+high)//2
            if nums[mid]==target:
                k=True
                break
            elif target>nums[mid]:
                low=mid+1
            else:
                high=mid-1
       if k:
            return mid
       else:
            return -1
obj=Solution()
obj.search([-1,0,3,5,9,12],9)
# Out:
# 4

# %% [markdown]
# ***Given an integer array nums, move all 0's to the end of it while maintaining the relative order of the non-zero elements.
# Note that you must do this in-place without making a copy of the array.
# Example 1:
# Input: nums = [0,1,0,3,12]
# Output: [1,3,12,0,0]
# Example 2:
# Input: nums = [0]
# Output: [0]***

# %%
class Solution:
    def moveZeroes(self, nums) -> None:
        '''if len(nums)==1:
            pass
        else:
            for i in range(len(nums)):
                for j in range(len(nums)-1):
                    if nums[j]==0:
                      nums[j],nums[j+1]=nums[j+1],nums[j]'''
        zeros=0
        for i in range(len(nums)):
            if nums[i]!=0:
                nums[zeros]=nums[i]
                zeros+=1
        for j in range(zeros,len(nums)):
            nums[j]=0
        return nums
obj=Solution()
print(obj.moveZeroes([0,1,0,3,12]))
# Out:
# [1, 3, 12, 0, 0]

# %% [markdown]
# ***The first line of input will contain a single integer denoting the number of test cases.Each test case consists of two lines of input.The first line of each test case contains a single integer the length of string The second line contains the string For each test case, output on a new line the answer: either yes or no ,After rearrangement, is it possible to make the first and last characters equal***

# %%
# cook your dish here
t=int(input())
for i in range(t):
    x=int(input())
    h=input()
    k=f"{h:.{x}}"
       
    if len(k)>0 and k[0]==k[x-1]:
        print("Yes")
    else:
        l=True
        for char in k:
            if k.count(char)>1:
                print("Yes")
                l=False
                break
        if l:
             print("No")
# Out:
# Yes
# Yes
# Yes

# %% [markdown]
# ***Given an integer array nums, return the third distinct maximum number in this array. If the third maximum does not exist, return the maximum number.
# Example 1:
# Input: nums = [3,2,1]
# Output: 1
# Explanation:
# The first distinct maximum is 3.
# The second distinct maximum is 2.
# The third distinct maximum is 1.
# Example 2:
# Input: nums = [1,2]
# Output: 2
# Explanation:
# The first distinct maximum is 2.
# The second distinct maximum is 1.
# The third distinct maximum does not exist, so the maximum (2) is returned instead.***

# %%
class Solution:
    def thirdMax(self, nums: List[int]) -> int:
        for i in range(len(nums)):
            for j in range(len(nums)-1):
                if nums[j]>nums[j+1]:
                    temp=nums[j]
                    nums[j]=nums[j+1]
                    nums[j+1]=temp
        res=[]
        for x in nums:
            if x not in res:
                res.append(x)
        if len(res)==1:
            return res[0]
        else:
            if len(res)-3 is not None:
                return res[len(res)-3]
            else:
                return res[len(res)-1]
obj=Solution() 
nums=[64,34,25,12,22,11,90] 
print(obj.thirdMax(nums))
# Out:
# 34

# %% [markdown]
# ***Given an integer array nums, find three numbers whose product is maximum and return the maximum product.
# Example 1:
# Input: nums = [1,2,3]
# Output: 6
# Example2 :
# Input: nums = [1,2,3,4]
# Output:24
# Example 3:
# Input: nums = [-1,-2,-3]
# Output:-6***

# %%
from typing import List
class Solution:
    def maximumProduct(self, nums: List[int]) -> int:
        '''for i in range(len(nums)):
            for j in range(len(nums)-1):
                if nums[j]>nums[j+1]:
                    temp=nums[j]
                    nums[j]=nums[j+1]
                    nums[j+1]=temp'''
        nums.sort()
        return max(nums[len(nums)-1]*nums[len(nums)-2]*nums[len(nums)-3],nums[0]*nums[1]*nums[len(nums)-1])
        '''res=[]
        for i in range(len(nums)):
            for j in range(i+1,len(nums)-1):
                for k in range(j+1,len(nums)):
                    res.append(nums[i]*nums[j]*nums[k])
        return max(res) '''           
        '''for i in range(len(res)):
            for j in range(len(res)-1):
                if res[j]>res[j+1]:
                    temp=res[j]
                    res[j]=res[j+1]
                    res[j+1]=temp
        return res[len(res)-1]  '''       


obj=Solution()
print(obj.maximumProduct([-10,-10,5,2]))
# Out:
# 500

# %% [markdown]
# ***Given a string s, find the length of the longest substring without duplicate characters.
# Example 1:
# Input: s = "abcabcbb"
# Output: 3
# Explanation: The answer is "abc", with the length of 3. Note that "bca" and "cab" are also correct answers.
# Example 2:
# Input: s = "bbbbb"
# Output: 1
# Explanation: The answer is "b", with the length of 1.
# Example 3:
# Input: s = "pwwkew"
# Output: 3
# Explanation: The answer is "wke", with the length of 3.
# Notice that the answer must be a substring, "pwke" is a subsequence and not a substring.***

# %%
class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        res=""
        le=[]
        for j in s:
            if j not in res:
                res=res+j
            else:
                
                le.append(len(res)) 
                '''while j in res:
                    res=res.replace(j,"")
                res=res+j'''
                index = res.index(j)
                res = res[index + 1:] + j
        le.append(len(res))
        if len(s)==0:
            return 0
        elif len(s)==1:
            return 1
        else:
          return max(le)  
obj=Solution()
print(obj.lengthOfLongestSubstring("abcabcbb"))
# Out:
# 3
